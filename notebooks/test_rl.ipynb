# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN

# %%
model = DQN(
    "MlpPolicy",
    "LunarLander-v3",
    verbose=1,
    exploration_final_eps=0.1,
    target_update_interval=250,
)
# Out:
# Using cuda device
# Creating environment from the given name 'LunarLander-v3'
# /home/aecohen/.conda/envs/pde-opt-env/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Separate env for evaluation
eval_env = gym.make("LunarLander-v3")

# Random Agent, before training
mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    deterministic=True,
)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /home/aecohen/.conda/envs/pde-opt-env/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-577.59 +/- 149.46317076120192

# %%
# Train the agent
model.learn(total_timesteps=int(1e5))
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -283     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 235      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 471      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12     |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -272     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 373      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 834      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.78     |
# |    n_updates        | 183      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -251     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 485      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1180     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 269      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 607      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1636     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.34     |
# |    n_updates        | 383      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -235     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 704      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2067     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07     |
# |    n_updates        | 491      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -226     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 793      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2558     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 614      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -230     |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 864      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3015     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.74     |
# |    n_updates        | 728      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 107      |
# |    ep_rew_mean      | -239     |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 920      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3429     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 832      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -236     |
# |    exploration_rate | 0.65     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 971      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3890     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.2      |
# |    n_updates        | 947      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -240     |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1014     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4327     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 1056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -237     |
# |    exploration_rate | 0.545    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1063     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 5057     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 1239     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | -231     |
# |    exploration_rate | 0.462    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1105     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 5977     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 1469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | -227     |
# |    exploration_rate | 0.344    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1114     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 7292     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31     |
# |    n_updates        | 1797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | -226     |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1133     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8316     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.54     |
# |    n_updates        | 2053     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1049     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 11177    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.9      |
# |    n_updates        | 2769     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1028     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14314    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.12     |
# |    n_updates        | 3553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | -223     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 992      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 17088    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.959    |
# |    n_updates        | 4246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 927      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 20709    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.787    |
# |    n_updates        | 5152     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 288      |
# |    ep_rew_mean      | -224     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 933      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 21899    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 5449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | -226     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 938      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 23448    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 5836     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 308      |
# |    ep_rew_mean      | -226     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 904      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 25850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01     |
# |    n_updates        | 6437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 339      |
# |    ep_rew_mean      | -222     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 847      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 29850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.05     |
# |    n_updates        | 7437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 368      |
# |    ep_rew_mean      | -217     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 832      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 33850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.863    |
# |    n_updates        | 8437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 394      |
# |    ep_rew_mean      | -212     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 822      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 37850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.01     |
# |    n_updates        | 9437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 418      |
# |    ep_rew_mean      | -206     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 826      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 41850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.78     |
# |    n_updates        | 10437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 454      |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 815      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 45850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.903    |
# |    n_updates        | 11437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 490      |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 812      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 49850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.734    |
# |    n_updates        | 12437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 810      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 53850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.515    |
# |    n_updates        | 13437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 562      |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 806      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 57850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.771    |
# |    n_updates        | 14437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 598      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 798      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 61850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.969    |
# |    n_updates        | 15437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 633      |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 792      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 65850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.578    |
# |    n_updates        | 16437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 668      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 784      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 69850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.642    |
# |    n_updates        | 17437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 704      |
# |    ep_rew_mean      | -157     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 781      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 73850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.566    |
# |    n_updates        | 18437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 740      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 778      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 77850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.595    |
# |    n_updates        | 19437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 775      |
# |    ep_rew_mean      | -144     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 777      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 81850    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.827    |
# |    n_updates        | 20437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 805      |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 776      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 85522    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.624    |
# |    n_updates        | 21355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 835      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 774      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 89522    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 22355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 862      |
# |    ep_rew_mean      | -131     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 771      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 93522    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 23355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 892      |
# |    ep_rew_mean      | -126     |
# |    exploration_rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 770      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 97522    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.857    |
# |    n_updates        | 24355    |
# ----------------------------------

# %%
model = DQN.load("dqn_lunar")

# %%
# Evaluate the trained agent
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=-85.09 +/- 28.522472286080287
